# %% [markdown]
# - HTML标签和属性
# ```html
# <标签 属性="属性值">
# <标签 />
# ```

# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'http://www.xinfadi.com.cn/getPriceData.html'
resp = requests.get(url)
resp.close()
lst = resp.json()['list']
print(lst)

# ## old ones
# page = bs(resp.text, 'html.parser') # 指定html解析器
# # find(标签, 属性=属性值)
# # find_all(标签, 属性=属性值)
# table = page.find('table', attrs={'class': 'hq_table'}) # table = page.find('table', class_='hq_table')
# trs = table.find_all('tr')[1:]
# for tr in trs:
#   tds = tr.find_all('td')
#   name = tds[0].text
#   low = tds[1].text
#   high = tds[2].text
