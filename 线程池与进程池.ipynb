# %%
# 线程池：向线程池提交任务，重复利用线程。实现线程任务调度
# 进程-资源单位   线程-执行单位
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

def fn(name):
  for i in range(1000):
    print(i)

# 创建线程池
with ThreadPoolExecutor(50) as t:
  for i in range(1000):
    t.submit(fn, name=i)
# 守护线程(进程)
