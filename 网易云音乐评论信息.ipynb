# %%
import requests

url = 'https://music.163.com/weapi/comment/resource/comments/get?csrf_token='
headers = {
  'User-Agent': ''
}

data = {
  "rid": "R_SO_4_1924858507",
  "threadId": "R_SO_4_1924858507",
  "pageNo": "1",
  "pageSize": "20",
  "cursor": "-1",
  "offset": "0",
  "orderType": "1",
  "csrf_token": ""
}

d = data
e = '010001'
f = ''
g = '0CoJUm6Qyw8W8jud'
i = "OLhcjp6GYkHr76Fm"
encSecKey = ""
# params'


# requests.post(url)

##
