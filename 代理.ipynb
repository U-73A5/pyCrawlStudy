# %%
import requests

url = 'https://www.baidu.com'
proxies = {
  # 'http': 'http://46.107.230.122:1080',
  'https': 'https://124.205.155.146:9090'
}

resp = requests.get(url, proxies=proxies)
resp.encoding = 'utf-8'
resp.close()
print(resp.text)
