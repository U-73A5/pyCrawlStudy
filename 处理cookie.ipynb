# %%
import requests

# 会话 > 进行一连串的请求，cookie不会丢失
session = requests.session()
data = {
  'loginName': '18335857673',
  'password': '123456a.'
}

url = 'https://passport.17k.com/ck/user/login'
resp = session.post(url, data=data)
resp.close()
# print(resp.cookies)

url = 'https://user.17k.com/ck/author/shelf?page=1&appKey=2406394919'
resp = session.get(url)
resp.close()
# print(resp.json())

# resp = requests.get('https://user.17k.com/ck/author/shelf?page=1&appKey=2406394919', headers= {
#   'Cookie': 'GUID=b3df3c20-94e5-49ca-b64c-98154baa55d9; sajssdk_2015_cross_new_user=1; c_channel=0; c_csc=web; accessToken=avatarUrl=https%3A%2F%2Fcdn.static.17k.com%2Fuser%2Favatar%2F12%2F32%2F13%2F94861332.jpg-88x88%3Fv%3D1648635761000&id=94861332&nickname=lluxx73zza5&e=1664188667&s=2391b194793cc6c8; sensorsdata2015jssdkcross={"distinct_id":"94861332","$device_id":"17fda548918758-0b60e67b7054e8-56171958-1327104-17fda54891973a","props":{"$latest_traffic_source_type":"引荐流量","$latest_referrer":"https://graph.qq.com/","$latest_referrer_host":"graph.qq.com","$latest_search_keyword":"未取到值"},"first_id":"b3df3c20-94e5-49ca-b64c-98154baa55d9"}'
# })
